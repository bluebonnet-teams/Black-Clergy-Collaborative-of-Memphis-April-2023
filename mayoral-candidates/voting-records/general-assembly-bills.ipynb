# %% [markdown]
# # LegiScan Datasets
#
# LegiScan very nicely provides well-formatted sources for all bills considered by state legislature.
#
# I've downloaded the TN House ones into a subfolder and this notebook parses out the relevant information.
#
# I manually merged the `people` directories from each session into a single one with all legislators from all sessions.

# %%
import pandas as pd
from pathlib import Path

# %%
# This folder has sub-folders for each legislative session
# as downloaded from LegiScan
root = Path('tn-house-bills')

# %%
people = pd.concat(
    [
        pd.read_json(person_json)
        for person_json in (root / 'people').glob('*.json')
    ],
    axis=1).T.set_index('people_id')[['name', 'last_name', 'party', 'role']]
people.head()
# Out:
#                         name   last_name party role
# people_id
# 7298            Jack Johnson     Johnson     R  Sen
# 7277             Diane Black       Black     R  Sen
# 12161             Don Miller      Miller     R  Rep
# 7220       Jeanne Richardson  Richardson     D  Rep
# 18645            Mark Lovell      Lovell     R  Rep

# %%
bills = pd.concat([
    pd.read_json(bill_json) for year_dir in root.glob('*General_Assembly')
    for bill_json in (year_dir / 'bill').glob('*.json')
    if year_dir.name != 'people' and year_dir.is_dir()
],
                  axis=1).T.set_index('bill_id')[[
                      'bill_number', 'bill_type', 'body', 'completed',
                      'description', 'session', 'sponsors', 'status',
                      'subjects', 'url', 'votes'
                  ]]
bills['subjects'] = [
    '; '.join([subj['subject_name'] for subj in subjects])
    for subjects in bills.subjects
]  # all bills actually appear to only have one subject
bills['category'] = bills['subjects'].str.split(', ').str[0]
bills.head()
# Out:
#         bill_number bill_type body completed  \
# bill_id
# 1078171      SB2524         B    S         1
# 948125       SB0519         B    S         0
# 943606      HJR0084        JR    H         1
# 1077899      HB2402         B    H         0
# 1075969      SB2174         B    S         1
#
#                                                description  \
# bill_id
# 1078171  As enacted, authorizes utility districts to en...
# 948125   As introduced, enacts the "Tennessee Retail Pe...
# 943606   Seth T. and Charlotte Bible, 50th wedding anni...
# 1077899  As introduced, requires the commissioner to pr...
# 1075969  As enacted, establishes requirements for issua...
#
#                                                    session  \
# bill_id
# 1078171  {'session_id': 1428, 'state_id': 42, 'year_sta...
# 948125   {'session_id': 1428, 'state_id': 42, 'year_sta...
# 943606   {'session_id': 1428, 'state_id': 42, 'year_sta...
# 1077899  {'session_id': 1428, 'state_id': 42, 'year_sta...
# 1075969  {'session_id': 1428, 'state_id': 42, 'year_sta...
#
#                                                   sponsors status  \
# bill_id
# 1078171  [{'people_id': 7274, 'person_hash': '9qzw4udj'...      4
# 948125   [{'people_id': 13706, 'person_hash': 'nnuu3olz...      2
# 943606   [{'people_id': 12069, 'person_hash': 'xv3b124h...      4
# 1077899  [{'people_id': 18636, 'person_hash': 'd07h6eqg...      1
# 1075969  [{'people_id': 15132, 'person_hash': '661zfjyf...      4
#
#                                  subjects  \
# bill_id
# 1078171      Utilities, Utility Districts
# 948125                               Pets
# 943606       Memorials, Personal Occasion
# 1077899  Commerce and Insurance, Dept. of
# 1075969                 Education, Higher
#
#                                                url  \
# bill_id
# 1078171   https://legiscan.com/TN/bill/SB2524/2017
# 948125    https://legiscan.com/TN/bill/SB0519/2017
# 943606   https://legiscan.com/TN/bill/HJR0084/2017
# 1077899   https://legiscan.com/TN/bill/HB2402/2017
# 1075969   https://legiscan.com/TN/bill/SB2174/2017
#
#                                                      votes  \
# bill_id
# 1078171  [{'roll_call_id': 723064, 'date': '2018-03-13'...
# 948125   [{'roll_call_id': 598336, 'date': '2017-03-06'...
# 943606   [{'roll_call_id': 577995, 'date': '2017-02-06'...
# 1077899                                                 []
# 1075969  [{'roll_call_id': 719163, 'date': '2018-03-07'...
#
#                        category
# bill_id
# 1078171               Utilities
# 948125                     Pets
# 943606                Memorials
# 1077899  Commerce and Insurance
# 1075969               Education

# %%
# Looking for just the last vote per bill
votes = pd.concat(
    [
        pd.read_json(vote_json) for year_dir in root.glob('*General_Assembly')
        for vote_json in (year_dir / 'vote').glob('*.json')
        if year_dir.name != 'people' and year_dir.is_dir()
    ],
    axis=1).T.pipe(lambda df: df[df['chamber'] == 'H']).sort_values(
        'date').groupby('bill_id').last()

# %%
# Karen Camper is our candidate of interest


def get_camper_vote(votes):
    for vote in votes:
        if vote['people_id'] == 7242:
            return vote['vote_text']
    return 'no record'


votes['camper_vote'] = votes.votes.apply(get_camper_vote)

# %%
combined = bills.join(votes[['camper_vote', 'yea', 'nay', 'total']])
combined['camper_sponsored'] = [
    any(sponsor['people_id'] == 7242 for sponsor in sponsor_set)
    for sponsor_set in bills['sponsors']
]
combined = combined.drop(
    columns=['votes', 'sponsors', 'completed']).fillna('no record')
combined['session'] = combined.session.str['session_title']
combined['status'] = combined['status'].replace({
    1: 'introduced',
    2: 'engrossed',
    3: 'enrolled',
    4: 'passed',
    6: 'failed'
})

# %%
combined.to_csv('tn-house-bills.csv')

# %%
combined
# Out:
#         bill_number bill_type body  \
# bill_id
# 1078171      SB2524         B    S
# 948125       SB0519         B    S
# 943606      HJR0084        JR    H
# 1077899      HB2402         B    H
# 1075969      SB2174         B    S
# ...             ...       ...  ...
# 1189618      SB0648         B    S
# 1180616      HB0294         B    H
# 1332143      SB2675         B    S
# 1330855      HB2753         B    H
# 1233614     SJR0287        JR    S
#
#                                                description  \
# bill_id
# 1078171  As enacted, authorizes utility districts to en...
# 948125   As introduced, enacts the "Tennessee Retail Pe...
# 943606   Seth T. and Charlotte Bible, 50th wedding anni...
# 1077899  As introduced, requires the commissioner to pr...
# 1075969  As enacted, establishes requirements for issua...
# ...                                                    ...
# 1189618  As enacted, allocates a portion of sales and u...
# 1180616  As introduced, allows, subject to available ap...
# 1332143  As introduced, changes the date, from August 1...
# 1330855  As introduced, reduces from 1,000 feet to 500 ...
# 1233614    Erin Wheatley, Top Ten, Spring Hill High School
#
#                            session      status  \
# bill_id
# 1078171  2017-2018 Regular Session      passed
# 948125   2017-2018 Regular Session   engrossed
# 943606   2017-2018 Regular Session      passed
# 1077899  2017-2018 Regular Session  introduced
# 1075969  2017-2018 Regular Session      passed
# ...                            ...         ...
# 1189618  2019-2020 Regular Session      passed
# 1180616  2019-2020 Regular Session  introduced
# 1332143  2019-2020 Regular Session  introduced
# 1330855  2019-2020 Regular Session  introduced
# 1233614  2019-2020 Regular Session      passed
#
#                                  subjects  \
# bill_id
# 1078171      Utilities, Utility Districts
# 948125                               Pets
# 943606       Memorials, Personal Occasion
# 1077899  Commerce and Insurance, Dept. of
# 1075969                 Education, Higher
# ...                                   ...
# 1189618                      Taxes, Sales
# 1180616                         Education
# 1332143                         Education
# 1330855                 Criminal Offenses
# 1233614   Memorials, Academic Achievement
#
#                                                url                category  \
# bill_id
# 1078171   https://legiscan.com/TN/bill/SB2524/2017               Utilities
# 948125    https://legiscan.com/TN/bill/SB0519/2017                    Pets
# 943606   https://legiscan.com/TN/bill/HJR0084/2017               Memorials
# 1077899   https://legiscan.com/TN/bill/HB2402/2017  Commerce and Insurance
# 1075969   https://legiscan.com/TN/bill/SB2174/2017               Education
# ...                                            ...                     ...
# 1189618   https://legiscan.com/TN/bill/SB0648/2019                   Taxes
# 1180616   https://legiscan.com/TN/bill/HB0294/2019               Education
# 1332143   https://legiscan.com/TN/bill/SB2675/2019               Education
# 1330855   https://legiscan.com/TN/bill/HB2753/2019       Criminal Offenses
# 1233614  https://legiscan.com/TN/bill/SJR0287/2019               Memorials
#
#         camper_vote        yea        nay      total  camper_sponsored
# bill_id
# 1078171         Yea       89.0        0.0       89.0             False
# 948125          Nay       45.0       47.0       94.0             False
# 943606          Yea       96.0        0.0       97.0             False
# 1077899   no record  no record  no record  no record             False
# 1075969         Yea       94.0        0.0       94.0             False
# ...             ...        ...        ...        ...               ...
# 1189618         Yea       94.0        0.0       95.0             False
# 1180616   no record  no record  no record  no record             False
# 1332143   no record  no record  no record  no record             False
# 1330855   no record  no record  no record  no record             False
# 1233614         Yea       97.0        0.0       97.0             False
#
# [43230 rows x 14 columns]
